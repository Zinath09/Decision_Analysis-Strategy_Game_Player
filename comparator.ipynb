# %%
# %matplotlib inline
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

from game import Game
from player import Player

# %%
from your_name import YourName

# %%
### Generate cards from 9 to 14 (ace) for all colors/symbols (0, 1, 2, 3)
def getDeck():
    return [(number, color) for color in range(4) for number in range(9, 15)]
    
print(getDeck())
# Out:
# [(9, 0), (10, 0), (11, 0), (12, 0), (13, 0), (14, 0), (9, 1), (10, 1), (11, 1), (12, 1), (13, 1), (14, 1), (9, 2), (10, 2), (11, 2), (12, 2), (13, 2), (14, 2), (9, 3), (10, 3), (11, 3), (12, 3), (13, 3), (14, 3)]

# %%
### Shuffle the cards randomly. Each player gets 9 cards
### (so one player cannot be certain which cards the other player has)

def getShuffled(deck):
    D = set(deck)
    A = set(random.sample(deck, 8))
    B = set(random.sample(list(D - A), 8))
    C = D - A - B
    if len(A.intersection(B)) > 0: print("Shuffle error 1")
    if len(A.intersection(B)) > 0: print("Shuffle error 2")
    if len(A.intersection(C)) > 0: print("Shuffle error 3") 
    DS = A | B | C
    if not DS == D: print("Shuffle error 4")  
    return list(A), list(B), list(C)

p1, p2, notUsed, = getShuffled(getDeck())
print(p1)
print(p2)
# Out:
# [(12, 1), (13, 1), (11, 0), (11, 3), (13, 0), (12, 3), (14, 0), (14, 3)]
# [(11, 1), (14, 1), (12, 0), (10, 1), (13, 3), (10, 0), (10, 3), (10, 2)]

# %%
# Some examplary random player

class RandomPlayer(Player):
    
    ### player's random strategy
    def putCard(self, declared_card):
        
        ### check if must draw
        if len(self.cards) == 1 and declared_card is not None and self.cards[0][0] < declared_card[0]:
            return "draw"
        
        ### player randomly decides which card put on the table
        card = random.choice(self.cards)
        declaration = card
        
        ### player randomly decides whether to cheat or not
        cheat = np.random.choice([True, False])
       
        ### if (s)he decides to cheat, (s)he randomly declares the card.
        if cheat:
            declaration = random.choice(self.cards)             
            
        ### Yet, declared card should be no worse than a card on the top of the pile . 
        if declared_card is not None and declaration[0] < declared_card[0]:
            declaration = (min(declared_card[0]+1,14), declaration[1])

        ### return the decision (true card) and declaration (player's declaration)
        return card, declaration
    
    
    ### randomly decides whether to check or not
    def checkCard(self, opponent_declaration):
        return np.random.choice([True, False])

# %% [markdown]
# Analyze few moves...

# %%
### Perform a full game 100 times
STAT_NAMES = ["Wins", "Draws", "Moves", "Cards", "Pile Size", "Checks", "Draw Decisions", "Cheats", "Errors", "Total errors"]
ANALYZE_STATS = [0, 1, 2, 3, 5, 6, 7, 8]

def printResults(results):
    print("Wins:")
    print(results[0])
    print("Draws:")
    print(results[1])
    print("Moves:")
    print(stats_moves[2])
    print("Cards:")
    print(results[3])
    print("Pile size:")
    print(results[4])
    print("Checks:")
    print(results[5])
    print("Draw decisions:")
    print(results[6])
    print("Cheats:")
    print(results[7])
    print("Errors:")
    print(results[8])
    print("Total errors:")
    print(results[9])

def comparePlayers(player1_class, player2_class):
    stats_wins = [0, 0]
    stats_draws = [0, 0]
    stats_moves = [0, 0]
    stats_cards = [0, 0]
    stats_pile_size = 0
    stats_checks = [0, 0]
    stats_draw_decisions = [0, 0]
    stats_cheats = [0, 0]
    stats_errors = [0, 0]
    
    repeats = 1
    errors = 0
    draws = 0

    for t in range(repeats):
        player1 = player1_class("")
        player2 = player2_class("")
        game = Game([player1, player2], log = True)
    
        error = False
        draw = False
        
        while True:
            valid, player = game.takeTurn(log = True)
            if game.moves[0] > 100 or game.moves[1] > 100:
                draws += 1
                stats_draws[0] += 1
                stats_draws[1] += 1
                if (game.player_cards[0] < game.player_cards[1]):
                    stats_wins[0] += 1
                if (game.player_cards[0] > game.player_cards[1]):
                    stats_wins[1] += 1
                    
                    
                draw=True
                print("DRAW")
                break
            if not valid:
                error = True
                stats_errors[player] += 1
                errors += 1
                break
            if game.isFinished(log = True):
                stats_wins[player] += 1
                break
            
        stats_pile_size += len(game.pile)
        if error: continue
        #if draw: continue
       
        for j in range(2):
            stats_moves[j] += game.moves[j]
            stats_cheats[j] += game.cheats[j]
            stats_checks[j] += game.checks[j]
            stats_draw_decisions[j] += game.draw_decisions[j]
            stats_cards[j] += len(game.player_cards[j])

    div = repeats - errors
    if div > 0:
            
        stats_pile_size /= div          
        for j in range(2):
            stats_moves[j] /= div
            stats_cheats[j] /= div
            stats_checks[j] /= div
            stats_draw_decisions[j] /= div
            stats_cards[j] /= div
            
    return [stats_wins, stats_draws, stats_moves, stats_cards, stats_pile_size, stats_checks, 
            stats_draw_decisions, stats_cheats, stats_errors, errors, draws]

# %% [markdown]
# # COMPARE

# %%
strategy = [["RandomPlayer", "RANDOM", RandomPlayer],
            ["YourName", "YourName", YourName],
           ]

# %%
#%pdb on
full_results = [[None for i in range(len(strategy))] for i in range(len(strategy))]

for A in range(len(strategy)):
    print("==== " + str(A), strategy[A][0])
    for B in range(A+1,len(strategy)):
        print(B, strategy[B][0])
        results = comparePlayers(strategy[A][2], strategy[B][2])
        full_results[A][B] = results
# Out:
# ==== 0 RandomPlayer
# 1 YourName
# Player (1):  received:
# [(11, 1), (12, 1), (9, 3), (11, 0), (9, 2), (13, 0), (13, 3), (11, 2)]
# Player (2):  received:
# [(9, 0), (13, 1), (14, 1), (14, 0), (10, 0), (12, 2), (13, 2), (10, 2)]
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(11, 1), (12, 1), (9, 3), (11, 0), (9, 2), (13, 0), (13, 3), (11, 2)]
# Player (1):  hand:
# [(9, 0), (13, 1), (14, 1), (14, 0), (10, 0), (12, 2), (13, 2), (10, 2)]
# Pile:
# []
# Declared top card:
# None
#
# [+]  puts (11, 2) and declares (11, 2)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(11, 1), (12, 1), (9, 3), (11, 0), (9, 2), (13, 0), (13, 3)]
# Player (1):  hand:
# [(9, 0), (13, 1), (14, 1), (14, 0), (10, 0), (12, 2), (13, 2), (10, 2)]
# Pile:
# [(11, 2)]
# Declared top card:
# (11, 2)
#
# [+]  puts (14, 1) and declares (14, 1)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(11, 1), (12, 1), (9, 3), (11, 0), (9, 2), (13, 0), (13, 3)]
# Player (1):  hand:
# [(9, 0), (10, 0), (10, 2), (12, 2), (13, 1), (13, 2), (14, 0)]
# Pile:
# [(11, 2), (14, 1)]
# Declared top card:
# (14, 1)
#
# [+]  puts (9, 2) and declares (14, 3)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(11, 1), (12, 1), (9, 3), (11, 0), (13, 0), (13, 3)]
# Player (1):  hand:
# [(9, 0), (10, 0), (10, 2), (12, 2), (13, 1), (13, 2), (14, 0)]
# Pile:
# [(11, 2), (14, 1), (9, 2)]
# Declared top card:
# (14, 3)
#
# [+]  puts (14, 0) and declares (14, 0)
# [!] : I want to check
# 	You are wrong!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = False; revealed card = None; number of taken cards = 3
# Feedback =  : checked this turn = True; I checked = True; I drew cards = True; revealed card = (14, 0); number of taken cards = 3
# Cards taken:
# [(14, 1), (9, 2), (14, 0)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(11, 1), (12, 1), (9, 3), (11, 0), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0)]
# Player (1):  hand:
# [(9, 0), (10, 0), (10, 2), (12, 2), (13, 1), (13, 2)]
# Pile:
# [(11, 2)]
# Declared top card:
# None
#
# [+]  puts (11, 1) and declares (11, 1)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(12, 1), (9, 3), (11, 0), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0)]
# Player (1):  hand:
# [(9, 0), (10, 0), (10, 2), (12, 2), (13, 1), (13, 2)]
# Pile:
# [(11, 2), (11, 1)]
# Declared top card:
# (11, 1)
#
# [+]  puts (13, 2) and declares (13, 2)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(12, 1), (9, 3), (11, 0), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0)]
# Player (1):  hand:
# [(9, 0), (10, 0), (10, 2), (12, 2), (13, 1)]
# Pile:
# [(11, 2), (11, 1), (13, 2)]
# Declared top card:
# (13, 2)
#
# [+]  puts (11, 0) and declares (14, 0)
# [!] : I want to check
# 	You are right!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = True; revealed card = None; number of taken cards = 3
# Feedback =  : checked this turn = True; I checked = True; I drew cards = False; revealed card = (11, 0); number of taken cards = 3
# Cards taken:
# [(11, 1), (13, 2), (11, 0)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(12, 1), (9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (11, 1), (13, 2), (11, 0)]
# Player (1):  hand:
# [(9, 0), (10, 0), (10, 2), (12, 2), (13, 1)]
# Pile:
# [(11, 2)]
# Declared top card:
# None
#
# [+]  puts (9, 0) and declares (9, 0)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(12, 1), (9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (11, 1), (13, 2), (11, 0)]
# Player (1):  hand:
# [(10, 0), (10, 2), (12, 2), (13, 1)]
# Pile:
# [(11, 2), (9, 0)]
# Declared top card:
# (9, 0)
#
# [+]  puts (11, 1) and declares (9, 3)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(12, 1), (9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0)]
# Player (1):  hand:
# [(10, 0), (10, 2), (12, 2), (13, 1)]
# Pile:
# [(11, 2), (9, 0), (11, 1)]
# Declared top card:
# (9, 3)
#
# [+]  puts (13, 1) and declares (13, 1)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(12, 1), (9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0)]
# Player (1):  hand:
# [(10, 0), (10, 2), (12, 2)]
# Pile:
# [(11, 2), (9, 0), (11, 1), (13, 1)]
# Declared top card:
# (13, 1)
#
# [+]  puts (12, 1) and declares (14, 1)
# [!] : I want to check
# 	You are right!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = True; revealed card = None; number of taken cards = 3
# Feedback =  : checked this turn = True; I checked = True; I drew cards = False; revealed card = (12, 1); number of taken cards = 3
# Cards taken:
# [(11, 1), (13, 1), (12, 1)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (12, 1)]
# Player (1):  hand:
# [(10, 0), (10, 2), (12, 2)]
# Pile:
# [(11, 2), (9, 0)]
# Declared top card:
# None
#
# [+]  puts (10, 0) and declares (10, 0)
# [!] : I want to check
# 	You are wrong!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = False; revealed card = None; number of taken cards = 3
# Feedback =  : checked this turn = True; I checked = True; I drew cards = True; revealed card = (10, 0); number of taken cards = 3
# Cards taken:
# [(11, 2), (9, 0), (10, 0)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (12, 1), (11, 2), (9, 0), (10, 0)]
# Player (1):  hand:
# [(10, 2), (12, 2)]
# Pile:
# []
# Declared top card:
# None
#
# [+]  puts (12, 1) and declares (12, 1)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (11, 2), (9, 0), (10, 0)]
# Player (1):  hand:
# [(10, 2), (12, 2)]
# Pile:
# [(12, 1)]
# Declared top card:
# (12, 1)
#
# [+]  puts (12, 2) and declares (12, 2)
# [!] : I want to check
# 	You are wrong!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = False; revealed card = None; number of taken cards = 2
# Feedback =  : checked this turn = True; I checked = True; I drew cards = True; revealed card = (12, 2); number of taken cards = 2
# Cards taken:
# [(12, 1), (12, 2)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (13, 0), (13, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (11, 2), (9, 0), (10, 0), (12, 1), (12, 2)]
# Player (1):  hand:
# [(10, 2)]
# Pile:
# []
# Declared top card:
# None
#
# [+]  puts (13, 3) and declares (13, 3)
# [!] : I want to check
# 	You are wrong!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = False; revealed card = None; number of taken cards = 1
# Feedback =  : checked this turn = True; I checked = True; I drew cards = True; revealed card = (13, 3); number of taken cards = 1
# Cards taken:
# [(13, 3)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (13, 0), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (11, 2), (9, 0), (10, 0), (12, 1), (12, 2)]
# Player (1):  hand:
# [(10, 2), (13, 3)]
# Pile:
# []
# Declared top card:
# None
#
# [+]  puts (10, 2) and declares (10, 2)
# [!] : I want to check
# 	You are wrong!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = False; revealed card = None; number of taken cards = 1
# Feedback =  : checked this turn = True; I checked = True; I drew cards = True; revealed card = (10, 2); number of taken cards = 1
# Cards taken:
# [(10, 2)]
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (13, 0), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (11, 2), (9, 0), (10, 0), (12, 1), (12, 2), (10, 2)]
# Player (1):  hand:
# [(13, 3)]
# Pile:
# []
# Declared top card:
# None
#
# [+]  puts (13, 0) and declares (13, 0)
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
# Feedback =  : checked this turn = False; I checked = False; I drew cards = False; revealed card = None; number of taken cards = None
#  wins!
#
#
# ==== CURRENT STATE ================================
# ====  MOVES ====
# Player (0):  hand:
# [(9, 3), (14, 1), (9, 2), (14, 0), (13, 2), (11, 0), (11, 1), (13, 1), (11, 2), (9, 0), (10, 0), (12, 1), (12, 2), (10, 2)]
# Player (1):  hand:
# [(13, 3)]
# Pile:
# [(13, 0)]
# Declared top card:
# (13, 0)
#
# [+]  puts (13, 3) and declares (13, 3)
# [!] : I want to check
# 	You are wrong!
# Feedback =  : checked this turn = True; I checked = False; I drew cards = False; revealed card = None; number of taken cards = 2
# Feedback =  : checked this turn = True; I checked = True; I drew cards = True; revealed card = (13, 3); number of taken cards = 2
# Cards taken:
# [(13, 0), (13, 3)]
#  wins!
#  wins!
# ==== 1 YourName

# %%
full_results
printResults()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 full_results
# ----> 2 printResults()
#
# TypeError: printResults() missing 1 required positional argument: 'results'

# %% [markdown]
# Simple stats

# %%
def printMatrix(full_results, stat):
    print(STAT_NAMES[stat])
    S = " "
    for s in strategy: S += (str(s[1]) + " " )
    print(S)
    for A in range(len(strategy)):
        print(A)
        S = str(strategy[A][1]) + " "
        for B in range(len(strategy)):
            if A == B: S += "- "
            elif A < B:
                S += str(full_results[A][B][stat][0]) + " "
            else:
                S += str(full_results[B][A][stat][1]) + " "
        print(S)
    
for a in ANALYZE_STATS:
    printMatrix(full_results, a)
